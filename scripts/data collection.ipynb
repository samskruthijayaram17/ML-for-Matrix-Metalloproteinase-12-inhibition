# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('Matrix metalloproteinase-12 homo sapiens')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#     cross_references               organism  \
# 0                 []           Homo sapiens
# 1                 []       Canis familiaris
# 2                 []      Rattus norvegicus
# 3                 []  Oryctolagus cuniculus
# 4                 []           Mus musculus
# ..               ...                    ...
# 337               []           Homo sapiens
# 338               []           Homo sapiens
# 339               []           Homo sapiens
# 340               []           Homo sapiens
# 341               []           Homo sapiens
#
#                                         pref_name  score  species_group_flag  \
# 0                                    Homo sapiens   37.0               False
# 1                     Matrix metalloproteinase-12   35.0               False
# 2                      Macrophage metalloelastase   32.0               False
# 3                      Macrophage metalloelastase   32.0               False
# 4                      Macrophage metalloelastase   31.0               False
# ..                                            ...    ...                 ...
# 337  Mitochondrial complex I (NADH dehydrogenase)    0.0               False
# 338                                26S proteasome    0.0               False
# 339                                20S proteasome    0.0               False
# 340                                  80S Ribosome    0.0               False
# 341                               Cytochrome P450    0.0               False
#
#     target_chembl_id                                  target_components  \
# 0          CHEMBL372                                                 []
# 1      CHEMBL1932900  [{'accession': 'A9X4R8', 'component_descriptio...
# 2         CHEMBL5506  [{'accession': 'Q63341', 'component_descriptio...
# 3      CHEMBL1932899  [{'accession': 'P79227', 'component_descriptio...
# 4         CHEMBL2594  [{'accession': 'P34960', 'component_descriptio...
# ..               ...                                                ...
# 337    CHEMBL2363065  [{'accession': 'P03923', 'component_descriptio...
# 338    CHEMBL2364701  [{'accession': 'Q99460', 'component_descriptio...
# 339    CHEMBL3831201  [{'accession': 'P49721', 'component_descriptio...
# 340    CHEMBL3987582  [{'accession': 'P08865', 'component_descriptio...
# 341    CHEMBL4523986  [{'accession': 'P08684', 'component_descriptio...
#
#                       target_type  tax_id
# 0                        ORGANISM    9606
# 1                  SINGLE PROTEIN    9615
# 2                  SINGLE PROTEIN   10116
# 3                  SINGLE PROTEIN    9986
# 4                  SINGLE PROTEIN   10090
# ..                            ...     ...
# 337               PROTEIN COMPLEX    9606
# 338               PROTEIN COMPLEX    9606
# 339         PROTEIN COMPLEX GROUP    9606
# 340  PROTEIN NUCLEIC-ACID COMPLEX    9606
# 341                PROTEIN FAMILY    9606
#
# [342 rows x 9 columns]

# %%
selected_target = targets.target_chembl_id[5]
selected_target
# Out:
# 'CHEMBL4393'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")
df = pd.DataFrame.from_dict(res)
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None   Not Determined       115929                  []
# 1        None             None       120889                  []
# 2        None             None       122085                  []
#
#   assay_chembl_id                              assay_description assay_type  \
# 0    CHEMBL716818  Inhibition of human Matrix metalloprotease-12          B
# 1    CHEMBL716818  Inhibition of human Matrix metalloprotease-12          B
# 2    CHEMBL716818  Inhibition of human Matrix metalloprotease-12          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
#
#   target_organism            target_pref_name target_tax_id text_value  toid  \
# 0    Homo sapiens  Macrophage metalloelastase          9606       None  None
# 1    Homo sapiens  Macrophage metalloelastase          9606       None  None
# 2    Homo sapiens  Macrophage metalloelastase          9606       None  None
#
#    type units    uo_units upper_value  value
# 0  IC50    uM  UO_0000065        None   None
# 1  IC50    uM  UO_0000065        None  0.042
# 2  IC50    uM  UO_0000065        None  0.012
#
# [3 rows x 46 columns]

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 1          None             None       120889                  []
# 2          None             None       122085                  []
# 3          None             None       124613                  []
# 4          None             None       129779                  []
# 5          None             None       143225                  []
# ..          ...              ...          ...                 ...
# 730        None          1285833     29023751                  []
# 731        None          1285834     29023754                  []
# 732        None          1285835     29023757                  []
# 733        None          1285836     29023760                  []
# 734        None          1285837     29023763                  []
#
#     assay_chembl_id                                  assay_description  \
# 1      CHEMBL716818      Inhibition of human Matrix metalloprotease-12
# 2      CHEMBL716818      Inhibition of human Matrix metalloprotease-12
# 3      CHEMBL716818      Inhibition of human Matrix metalloprotease-12
# 4      CHEMBL716818      Inhibition of human Matrix metalloprotease-12
# 5      CHEMBL716818      Inhibition of human Matrix metalloprotease-12
# ..              ...                                                ...
# 730   CHEMBL5739420  MMP Inhibitory Assay: The inhibitory effect of...
# 731   CHEMBL5739420  MMP Inhibitory Assay: The inhibitory effect of...
# 732   CHEMBL5739420  MMP Inhibitory Assay: The inhibitory effect of...
# 733   CHEMBL5739420  MMP Inhibitory Assay: The inhibitory effect of...
# 734   CHEMBL5739420  MMP Inhibitory Assay: The inhibitory effect of...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# 5            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 730          B                    None                   None  BAO_0000190
# 731          B                    None                   None  BAO_0000190
# 732          B                    None                   None  BAO_0000190
# 733          B                    None                   None  BAO_0000190
# 734          B                    None                   None  BAO_0000190
#
#      ... target_organism            target_pref_name target_tax_id text_value  \
# 1    ...    Homo sapiens  Macrophage metalloelastase          9606       None
# 2    ...    Homo sapiens  Macrophage metalloelastase          9606       None
# 3    ...    Homo sapiens  Macrophage metalloelastase          9606       None
# 4    ...    Homo sapiens  Macrophage metalloelastase          9606       None
# 5    ...    Homo sapiens  Macrophage metalloelastase          9606       None
# ..   ...             ...                         ...           ...        ...
# 730  ...    Homo sapiens  Macrophage metalloelastase          9606       None
# 731  ...    Homo sapiens  Macrophage metalloelastase          9606       None
# 732  ...    Homo sapiens  Macrophage metalloelastase          9606       None
# 733  ...    Homo sapiens  Macrophage metalloelastase          9606       None
# 734  ...    Homo sapiens  Macrophage metalloelastase          9606       None
#
#      toid  type units    uo_units upper_value  value
# 1    None  IC50    uM  UO_0000065        None  0.042
# 2    None  IC50    uM  UO_0000065        None  0.012
# 3    None  IC50    uM  UO_0000065        None  0.009
# 4    None  IC50    uM  UO_0000065        None  0.014
# 5    None  IC50    uM  UO_0000065        None  0.013
# ..    ...   ...   ...         ...         ...    ...
# 730  None  IC50    nM  UO_0000065        None    1.0
# 731  None  IC50    nM  UO_0000065        None    1.0
# 732  None  IC50    nM  UO_0000065        None    1.0
# 733  None  IC50    nM  UO_0000065        None    1.0
# 734  None  IC50    nM  UO_0000065        None    1.0
#
# [691 rows x 46 columns]

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL1788203               CCCC[C@H](CC(=O)NO)S(=O)(=O)c1ccccc1
# 1         CHEMBL263501                   CCCCC(CC(=O)NO)S(=O)(=O)c1ccccc1
# 2        CHEMBL2092878              CCCC[C@@H](CC(=O)NO)S(=O)(=O)c1ccccc1
# 3          CHEMBL77258                   CCCCC(CC(=O)NO)S(=O)(=O)C1CCCCC1
# 4          CHEMBL78001             CCCCC(CC(=O)NO)S(=O)(=O)c1ccc2ccccc2c1
# ..                 ...                                                ...
# 686      CHEMBL5742512  CCC1(c2cnccc2Sc2ccc(/C=C/c3ccnc(C)c3)cc2)NC(=O...
# 687      CHEMBL5800908      Cc1cc(C#Cc2ccc(Sc3ccsc3C3NC(=O)NC3=O)cc2)ccn1
# 688      CHEMBL6006240    Cc1cc(/C=C/c2ccc(Sc3ccsc3C3NC(=O)NC3=O)cc2)ccn1
# 689      CHEMBL5761540   Cc1cc(C#Cc2ccc(Sc3cnn(C)c3C3NC(=O)NC3=O)cc2)ccn1
# 690      CHEMBL6013997  Cc1cc(/C=C/c2ccc(Sc3cnn(C)c3C3NC(=O)NC3=O)cc2)...
#
#     bioactivity_class standard_value
# 0              active           42.0
# 1              active           12.0
# 2              active            9.0
# 3              active           14.0
# 4              active           13.0
# ..                ...            ...
# 686            active            1.0
# 687            active            1.0
# 688            active            1.0
# 689            active            1.0
# 690            active            1.0
#
# [691 rows x 4 columns]

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL1788203               CCCC[C@H](CC(=O)NO)S(=O)(=O)c1ccccc1
# 1         CHEMBL263501                   CCCCC(CC(=O)NO)S(=O)(=O)c1ccccc1
# 2        CHEMBL2092878              CCCC[C@@H](CC(=O)NO)S(=O)(=O)c1ccccc1
# 3          CHEMBL77258                   CCCCC(CC(=O)NO)S(=O)(=O)C1CCCCC1
# 4          CHEMBL78001             CCCCC(CC(=O)NO)S(=O)(=O)c1ccc2ccccc2c1
# ..                 ...                                                ...
# 686      CHEMBL5742512  CCC1(c2cnccc2Sc2ccc(/C=C/c3ccnc(C)c3)cc2)NC(=O...
# 687      CHEMBL5800908      Cc1cc(C#Cc2ccc(Sc3ccsc3C3NC(=O)NC3=O)cc2)ccn1
# 688      CHEMBL6006240    Cc1cc(/C=C/c2ccc(Sc3ccsc3C3NC(=O)NC3=O)cc2)ccn1
# 689      CHEMBL5761540   Cc1cc(C#Cc2ccc(Sc3cnn(C)c3C3NC(=O)NC3=O)cc2)ccn1
# 690      CHEMBL6013997  Cc1cc(/C=C/c2ccc(Sc3cnn(C)c3C3NC(=O)NC3=O)cc2)...
#
#     bioactivity_class standard_value       0
# 0              active           42.0  active
# 1              active           12.0  active
# 2              active            9.0  active
# 3              active           14.0  active
# 4              active           13.0  active
# ..                ...            ...     ...
# 686            active            1.0  active
# 687            active            1.0  active
# 688            active            1.0  active
# 689            active            1.0  active
# 690            active            1.0  active
#
# [691 rows x 5 columns]

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
